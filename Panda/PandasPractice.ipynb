# %%
import pandas as pd

# %%
data = {
    "Name" : ["Natansh","Dushyant","Aman","Navneet"],
    "Eid" : [75,37,17,76],
    "Age" : [20,19,19,19],
}
df = pd.DataFrame(data)
print(df)
# Out:
#        Name  Eid  Age
# 0   Natansh   75   20
# 1  Dushyant   37   19
# 2      Aman   17   19
# 3   Navneet   76   19

# %%
data = pd.read_csv("/Airline Quality Ratings cleaned 2.csv")
print(data)
# Out:
#             ID  Gender  Age Customer Type Type of Travel         Class  \
# 0            1    Male   48    First-time       Business      Business
# 1            2  Female   35     Returning       Business      Business
# 2            3    Male   41     Returning       Business      Business
# 3            4    Male   50     Returning       Business      Business
# 4            5  Female   49     Returning       Business      Business
# ...        ...     ...  ...           ...            ...           ...
# 129875  129876    Male   28     Returning       Personal  Economy Plus
# 129876  129877    Male   41     Returning       Personal  Economy Plus
# 129877  129878    Male   42     Returning       Personal  Economy Plus
# 129878  129879    Male   50     Returning       Personal  Economy Plus
# 129879  129880  Female   20     Returning       Personal  Economy Plus
#
#         Flight Distance  Departure Delay  Arrival Delay  \
# 0                   821                2              5
# ...

# %%
excelData = pd.read_excel("/Travel-Expense-Calculator.xlsx")
print(excelData.head(10))
# Out:
#    Unnamed: 0 Unnamed: 1          Unnamed: 2           Unnamed: 3 Unnamed: 4  \
# 0         NaN        NaN                 NaN                  NaN        NaN
# 1         NaN        NaN     Employee Name:              John Doe        NaN
# 2         NaN        NaN                 NaN                  NaN        NaN
# 3         NaN        NaN       Employee ID:               JD12345        NaN
# 4         NaN        NaN                 NaN                  NaN        NaN
# 5         NaN        NaN         Department:            Marketing        NaN
# 6         NaN        NaN                 NaN                  NaN        NaN
# 7         NaN        NaN  Travel Start Date:  2050-06-15 00:00:00        NaN
# 8         NaN        NaN                 NaN                  NaN        NaN
# 9         NaN        NaN   Travel End Date:   2050-06-20 00:00:00        NaN
#
#    Unnamed: 5 Unnamed: 6                 Unnamed: 7 Unnamed: 8  Unnamed: 9  \
# ...

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 26 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   ID                                      129880 non-null  int64
#  1   Gender                                  129880 non-null  object
#  2   Age                                     129880 non-null  int64
#  3   Customer Type                           129880 non-null  object
#  4   Type of Travel                          129880 non-null  object
#  5   Class                                   129880 non-null  object
#  6   Flight Distance                         129880 non-null  int64
#  7   Departure Delay                         129880 non-null  int64
#  8   Arrival Delay                           129880 non-null  int64
#  9   Departure and Arrival Time Convenience  129880 non-null  int64
# ...

# %%
print(excelData.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   0 non-null      float64
#  1   Unnamed: 1   1 non-null      object
#  2   Unnamed: 2   14 non-null     object
#  3   Unnamed: 3   9 non-null      object
#  4   Unnamed: 4   3 non-null      object
#  5   Unnamed: 5   0 non-null      float64
#  6   Unnamed: 6   6 non-null      object
#  7   Unnamed: 7   4 non-null      object
#  8   Unnamed: 8   6 non-null      object
#  9   Unnamed: 9   0 non-null      float64
#  10  Unnamed: 10  9 non-null      object
#  11  Unnamed: 11  3 non-null      object
#  12  Unnamed: 12  4 non-null      object
#  13  Unnamed: 13  0 non-null      float64
#  14  Unnamed: 14  12 non-null     object
#  15  Unnamed: 15  6 non-null      object
#  16  Unnamed: 16  7 non-null      object
#  17  Unnamed: 17  0 non-null      float64
# ...

# %%
print(data.describe())
# Out:
#                   ID            Age  Flight Distance  Departure Delay  \
# count  129880.000000  129880.000000    129880.000000    129880.000000
# mean    64940.500000      39.427957      1190.316392        14.713713
# std     37493.270818      15.119360       997.452477        38.071126
# min         1.000000       7.000000        31.000000         0.000000
# 25%     32470.750000      27.000000       414.000000         0.000000
# 50%     64940.500000      40.000000       844.000000         0.000000
# 75%     97410.250000      51.000000      1744.000000        12.000000
# max    129880.000000      85.000000      4983.000000      1592.000000
#
#        Arrival Delay  Departure and Arrival Time Convenience  \
# count  129880.000000                           129880.000000
# mean       15.045465                                3.057599
# std        38.416353                                1.526741
# min         0.000000                                0.000000
# ...

# %%
print(data["ID"].duplicated().sum())
# Out:
# 0

# %%
print(data)
# Out:
#             ID  Gender  Age Customer Type Type of Travel         Class  \
# 0            1    Male   48    First-time       Business      Business
# 1            2  Female   35     Returning       Business      Business
# 2            3    Male   41     Returning       Business      Business
# 3            4    Male   50     Returning       Business      Business
# 4            5  Female   49     Returning       Business      Business
# ...        ...     ...  ...           ...            ...           ...
# 129875  129876    Male   28     Returning       Personal  Economy Plus
# 129876  129877    Male   41     Returning       Personal  Economy Plus
# 129877  129878    Male   42     Returning       Personal  Economy Plus
# 129878  129879    Male   50     Returning       Personal  Economy Plus
# 129879  129880  Female   20     Returning       Personal  Economy Plus
#
#         Flight Distance  Departure Delay  Arrival Delay  \
# 0                   821                2              5
# ...

# %%
print(data.isnull().sum())
# Out:
# ID                                            0
# Gender                                        0
# Age                                           0
# Customer Type                                 0
# Type of Travel                                0
# Class                                         0
# Flight Distance                               0
# Departure Delay                               0
# Arrival Delay                                 0
# Departure and Arrival Time Convenience        0
# Ease of Online Booking                        0
# Check-in Service                              0
# Online Boarding                               0
# Gate Location                                 0
# On-board Service                              0
# Seat Comfort                                  0
# Leg Room Service                              0
# Cleanliness                                   0
# Food and Drink                                0
# In-flight Service                             0
# ...

# %%
import numpy as np
data["Satisfied Customers"] = data["Satisfied Customers"].replace(np.nan, "UnSatisfied")

# %%
print(data.isnull().sum())
# Out:
# ID                                            0
# Gender                                        0
# Age                                           0
# Customer Type                                 0
# Type of Travel                                0
# Class                                         0
# Flight Distance                               0
# Departure Delay                               0
# Arrival Delay                                 0
# Departure and Arrival Time Convenience        0
# Ease of Online Booking                        0
# Check-in Service                              0
# Online Boarding                               0
# Gate Location                                 0
# On-board Service                              0
# Seat Comfort                                  0
# Leg Room Service                              0
# Cleanliness                                   0
# Food and Drink                                0
# In-flight Service                             0
# ...

# %%
print(data.head(20))
# Out:
#     ID  Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# 0    1    Male   48    First-time       Business  Business              821
# 1    2  Female   35     Returning       Business  Business              821
# 2    3    Male   41     Returning       Business  Business              853
# 3    4    Male   50     Returning       Business  Business             1905
# 4    5  Female   49     Returning       Business  Business             3470
# 5    6    Male   43     Returning       Business  Business             3788
# 6    7    Male   43     Returning       Business  Business             1963
# 7    8  Female   60     Returning       Business  Business              853
# 8    9    Male   50     Returning       Business  Business             2607
# 9   10  Female   38     Returning       Business  Business             2822
# 10  11  Female   28    First-time       Business  Business              821
# ...

# %%
data.loc[(data["Age"]>18), "Age Category"] = "Adult"
data.loc[(data["Age"] <= 18), "Age Category"] = "Young"
print(data.head(30))
# Out:
#     ID  Gender  Age Customer Type Type of Travel         Class  \
# 0    1    Male   48    First-time       Business      Business
# 1    2  Female   35     Returning       Business      Business
# 2    3    Male   41     Returning       Business      Business
# 3    4    Male   50     Returning       Business      Business
# 4    5  Female   49     Returning       Business      Business
# 5    6    Male   43     Returning       Business      Business
# 6    7    Male   43     Returning       Business      Business
# 7    8  Female   60     Returning       Business      Business
# 8    9    Male   50     Returning       Business      Business
# 9   10  Female   38     Returning       Business      Business
# 10  11  Female   28    First-time       Business      Business
# 11  12  Female   27    First-time       Business      Business
# 12  13    Male   24    First-time       Business       Economy
# 13  14    Male    9     Returning       Personal      Business
# ...
