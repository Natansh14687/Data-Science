# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.0.3'

# %%
data1=pd.read_csv("spotify_long_tracks_2014_2024.csv")

# %%
data1
# Out:
#                          ID  \
# 0    026O2YP2wRl9h3Ht9ClZST
# 1    0DXnjJxJBvgMvBjG6Jug7I
# 2    6BFn78qFy9bRqKHTMfhnNv
# 3    1dNwMOMtq3yflXibbqgLku
# 4    290gfei8moWWSh8qTVkTT3
# ..                      ...
# 811  0OYbUI94jw0vLQeAmKKZ53
# 812  4Wmjr8wNvU4O3tj3CXRmkE
# 813  465EdPfedCDmofyICPGmiF
# 814  2NNBTCfzAgyolaaZNNzD4O
# 815  5dB5tmSZ4hoUY36tSkPoxt
#
#                                                   Name  Duration (Minutes)  \
# 0    Steady Rain in a Forest with Light Background ...                 100
# 1                                     Soundarya Lahari                  66
# 2                    Waves of Abundance & Fullfillment                  60
# 3    Mosquito Solution Anti Teen Street Party or Te...                  45
# 4    Ibiza Sunset Tibetan Singing Bowl Sessions 7 (...                  44
# ..                                                 ...                 ...
# 811                                            Keep On                   5
# ...

# %%
data1.head()
# Out:
#                        ID                                               Name  \
# 0  026O2YP2wRl9h3Ht9ClZST  Steady Rain in a Forest with Light Background ...
# 1  0DXnjJxJBvgMvBjG6Jug7I                                   Soundarya Lahari
# 2  6BFn78qFy9bRqKHTMfhnNv                  Waves of Abundance & Fullfillment
# 3  1dNwMOMtq3yflXibbqgLku  Mosquito Solution Anti Teen Street Party or Te...
# 4  290gfei8moWWSh8qTVkTT3  Ibiza Sunset Tibetan Singing Bowl Sessions 7 (...
#
#    Duration (Minutes)                Artists
# 0                 100          Nature Sounds
# 1                  66       Mambalam Sisters
# 2                  60         Zen Life Relax
# 3                  45    Device Sound Effect
# 4                  44  Tibetan Singing Bowls

# %%
data1.head(8)
# Out:
#                        ID                                               Name  \
# 0  026O2YP2wRl9h3Ht9ClZST  Steady Rain in a Forest with Light Background ...
# 1  0DXnjJxJBvgMvBjG6Jug7I                                   Soundarya Lahari
# 2  6BFn78qFy9bRqKHTMfhnNv                  Waves of Abundance & Fullfillment
# 3  1dNwMOMtq3yflXibbqgLku  Mosquito Solution Anti Teen Street Party or Te...
# 4  290gfei8moWWSh8qTVkTT3  Ibiza Sunset Tibetan Singing Bowl Sessions 7 (...
# 5  23ordmf2KkRfHh9zE9RVyq                                                 佃祭
# 6  47iSvlaCBugj3HrGZDZYcO                        Tālā Gaisma (Distant Light)
# 7  6fKZZf5Mws3hr31ZAvCOcs                          Asmr Tea Massage Roleplay
#
#    Duration (Minutes)                                            Artists
# 0                 100                                      Nature Sounds
# 1                  66                                   Mambalam Sisters
# ...

# %%
data1.tail()
# Out:
#                          ID                        Name  Duration (Minutes)  \
# 811  0OYbUI94jw0vLQeAmKKZ53                     Keep On                   5
# 812  4Wmjr8wNvU4O3tj3CXRmkE        雨の街 - Re:Lilly remix                   5
# 813  465EdPfedCDmofyICPGmiF    Měla Jsem Vrásky Na Čele                   5
# 814  2NNBTCfzAgyolaaZNNzD4O  ARIGATOUNO WA - Cover ver.                   5
# 815  5dB5tmSZ4hoUY36tSkPoxt                  Alt Barbat                   5
#
#              Artists
# 811          Vanilla
# 812         Re:Lilly
# 813  Jana Rychterová
# 814        Baby Band
# 815          Mellina

# %%
data1.tail(8)
# Out:
#                          ID                                    Name  \
# 808  2ygEuxlruHbNExTpYEf114                            Soon Forward
# 809  1ZqyyPtqmuF2NIgM1Q4HQU                                  Katigu
# 810  0bfR5yS6O5iBtPcy3osb4o  Filho Bonito (Beautiful Boy) - Ao Vivo
# 811  0OYbUI94jw0vLQeAmKKZ53                                 Keep On
# 812  4Wmjr8wNvU4O3tj3CXRmkE                    雨の街 - Re:Lilly remix
# 813  465EdPfedCDmofyICPGmiF                Měla Jsem Vrásky Na Čele
# 814  2NNBTCfzAgyolaaZNNzD4O              ARIGATOUNO WA - Cover ver.
# 815  5dB5tmSZ4hoUY36tSkPoxt                              Alt Barbat
#
#      Duration (Minutes)                          Artists
# 808                   5                   Gregory Isaacs
# 809                   5  JayRex SuiSui, Jharvii, Robby T
# 810                   5                           Mãeana
# 811                   5                          Vanilla
# 812                   5                         Re:Lilly
# ...

# %%
ser=data1["Duration (Minutes)"]

# %%
ser
# Out:
# 0      100
# 1       66
# 2       60
# 3       45
# 4       44
#       ...
# 811      5
# 812      5
# 813      5
# 814      5
# 815      5
# Name: Duration (Minutes), Length: 816, dtype: int64

# %%
ser.describe()
# Out:
# count    816.000000
# mean       6.980392
# std        5.907642
# min        5.000000
# 25%        5.000000
# 50%        6.000000
# 75%        7.000000
# max      100.000000
# Name: Duration (Minutes), dtype: float64

# %%
data1.shape
# Out:
# (816, 4)

# %%
data1.columns
# Out:
# Index(['ID', 'Name', 'Duration (Minutes)', 'Artists'], dtype='object')

# %%
data1.dtypes
# Out:
# ID                    object
# Name                  object
# Duration (Minutes)     int64
# Artists               object
# dtype: object

# %%
data1.Artists.value_counts()
# Out:
# Artists
# Suara                    2
# Joachim Pastor           2
# Tangerine Dream          2
# Nusrat Fateh Ali Khan    2
# Nature Sounds            1
#                         ..
# Fernando Velázquez       1
# NMR Digital              1
# Neil Diamond             1
# European Jazz Trio       1
# Mellina                  1
# Name: count, Length: 812, dtype: int64

# %%
data1.Artists.value_counts().max()
# Out:
# 2

# %%
data1
# Out:
#                          ID  \
# 0    026O2YP2wRl9h3Ht9ClZST
# 1    0DXnjJxJBvgMvBjG6Jug7I
# 2    6BFn78qFy9bRqKHTMfhnNv
# 3    1dNwMOMtq3yflXibbqgLku
# 4    290gfei8moWWSh8qTVkTT3
# ..                      ...
# 811  0OYbUI94jw0vLQeAmKKZ53
# 812  4Wmjr8wNvU4O3tj3CXRmkE
# 813  465EdPfedCDmofyICPGmiF
# 814  2NNBTCfzAgyolaaZNNzD4O
# 815  5dB5tmSZ4hoUY36tSkPoxt
#
#                                                   Name  Duration (Minutes)  \
# 0    Steady Rain in a Forest with Light Background ...                 100
# 1                                     Soundarya Lahari                  66
# 2                    Waves of Abundance & Fullfillment                  60
# 3    Mosquito Solution Anti Teen Street Party or Te...                  45
# 4    Ibiza Sunset Tibetan Singing Bowl Sessions 7 (...                  44
# ..                                                 ...                 ...
# 811                                            Keep On                   5
# ...

# %%
unique=data1["Duration (Minutes)"].value_counts()

# %%
unique
# Out:
# Duration (Minutes)
# 5      379
# 6      204
# 7       96
# 8       55
# 9       20
# 10       8
# 11       8
# 13       6
# 12       6
# 15       6
# 20       4
# 30       2
# 29       2
# 28       2
# 27       2
# 14       2
# 18       2
# 100      1
# 16       1
# 66       1
# 22       1
# 31       1
# 32       1
# 33       1
# 35       1
# 44       1
# 45       1
# 60       1
# 21       1
# Name: count, dtype: int64

# %%
unique.sum()
# Out:
# 816

# %%
379/816
# Out:
# 0.4644607843137255

# %%
data1.columns
# Out:
# Index(['ID', 'Name', 'Duration (Minutes)', 'Artists'], dtype='object')

# %%
data1["Duration (Minutes)"].value_counts(normalize=True)
# Out:
# Duration (Minutes)
# 5      0.464461
# 6      0.250000
# 7      0.117647
# 8      0.067402
# 9      0.024510
# 10     0.009804
# 11     0.009804
# 13     0.007353
# 12     0.007353
# 15     0.007353
# 20     0.004902
# 30     0.002451
# 29     0.002451
# 28     0.002451
# 27     0.002451
# 14     0.002451
# 18     0.002451
# 100    0.001225
# 16     0.001225
# 66     0.001225
# 22     0.001225
# 31     0.001225
# 32     0.001225
# 33     0.001225
# 35     0.001225
# 44     0.001225
# 45     0.001225
# 60     0.001225
# 21     0.001225
# Name: proportion, dtype: float64

# %%
data1["Duration (Minutes)"].unique()
# Out:
# array([100,  66,  60,  45,  44,  35,  33,  32,  31,  30,  29,  28,  27,
#         22,  21,  20,  18,  16,  15,  14,  13,  12,  11,  10,   9,   8,
#          7,   6,   5], dtype=int64)

# %%
data1["Duration (Minutes)"].nunique()
# Out:
# 29

# %%
data1
# Out:
#                          ID  \
# 0    026O2YP2wRl9h3Ht9ClZST
# 1    0DXnjJxJBvgMvBjG6Jug7I
# 2    6BFn78qFy9bRqKHTMfhnNv
# 3    1dNwMOMtq3yflXibbqgLku
# 4    290gfei8moWWSh8qTVkTT3
# ..                      ...
# 811  0OYbUI94jw0vLQeAmKKZ53
# 812  4Wmjr8wNvU4O3tj3CXRmkE
# 813  465EdPfedCDmofyICPGmiF
# 814  2NNBTCfzAgyolaaZNNzD4O
# 815  5dB5tmSZ4hoUY36tSkPoxt
#
#                                                   Name  Duration (Minutes)  \
# 0    Steady Rain in a Forest with Light Background ...                 100
# 1                                     Soundarya Lahari                  66
# 2                    Waves of Abundance & Fullfillment                  60
# 3    Mosquito Solution Anti Teen Street Party or Te...                  45
# 4    Ibiza Sunset Tibetan Singing Bowl Sessions 7 (...                  44
# ..                                                 ...                 ...
# 811                                            Keep On                   5
# ...

# %%
data2=pd.read_csv("DiseaseAndSymptoms.csv")

# %%
data2
# Out:
#                                       Disease             Symptom_1  \
# 0                            Fungal infection               itching
# 1                            Fungal infection             skin_rash
# 2                            Fungal infection               itching
# 3                            Fungal infection               itching
# 4                            Fungal infection               itching
# ...                                       ...                   ...
# 4915  (vertigo) Paroymsal  Positional Vertigo              vomiting
# 4916                                     Acne             skin_rash
# 4917                  Urinary tract infection   burning_micturition
# 4918                                Psoriasis             skin_rash
# 4919                                 Impetigo             skin_rash
#
#                   Symptom_2              Symptom_3                  Symptom_4  \
# ...

# %%
data2["Disease"].value_counts()
# Out:
# Disease
# Fungal infection                           120
# Hepatitis C                                120
# Hepatitis E                                120
# Alcoholic hepatitis                        120
# Tuberculosis                               120
# Common Cold                                120
# Pneumonia                                  120
# Dimorphic hemmorhoids(piles)               120
# Heart attack                               120
# Varicose veins                             120
# Hypothyroidism                             120
# Hyperthyroidism                            120
# Hypoglycemia                               120
# Osteoarthristis                            120
# Arthritis                                  120
# (vertigo) Paroymsal  Positional Vertigo    120
# Acne                                       120
# Urinary tract infection                    120
# Psoriasis                                  120
# Hepatitis D                                120
# ...

# %%
data2.Symptom_1.value_counts()
# Out:
# Symptom_1
#  vomiting                       822
#  fatigue                        690
# itching                         678
#  skin_rash                      480
#  chills                         474
#  joint_pain                     462
#  continuous_sneezing            222
#  headache                       126
#  acidity                        120
#  stomach_pain                   114
#  constipation                   114
#  muscle_weakness                114
#  burning_micturition            108
#  muscle_wasting                 108
#  back_pain                      108
#  bladder_discomfort              12
#  weight_gain                     12
#  breathlessness                  12
#  yellowish_skin                  12
#  weakness_in_limbs               12
#  chest_pain                      12
#  cough                           12
#  sunken_eyes                     12
#  patches_in_throat               12
#  indigestion                     12
#  shivering                       12
# ...

# %%
data2.Symptom_2.value_counts()
# Out:
# Symptom_2
#  vomiting                       870
#  fatigue                        402
#  skin_rash                      306
#  chills                         240
#  yellowish_skin                 240
#  headache                       216
#  indigestion                    210
#  high_fever                     156
#  neck_pain                      132
#  weight_loss                    120
#  joint_pain                     120
#  pain_during_bowel_movements    108
#  stiff_neck                     108
#  mood_swings                    108
#  cough                          108
#  cramps                         108
#  acidity                        102
#  bladder_discomfort             102
#  pus_filled_pimples             102
#  weight_gain                    102
#  breathlessness                  96
#  patches_in_throat               96
#  chest_pain                      96
#  shivering                       96
#  sunken_eyes                     96
#  weakness_in_limbs               96
# ...

# %%
data2.Symptom_3.value_counts()
# Out:
# Symptom_3
#  fatigue                         726
#  high_fever                      324
#  yellowish_skin                  240
#  nausea                          222
#  lethargy                        138
#  weight_loss                     138
#  abdominal_pain                  132
#  cough                           120
#  sweating                        120
#  restlessness                    120
#  dizziness                       114
#  loss_of_appetite                108
#  knee_pain                       102
#  joint_pain                      102
#  pain_in_anal_region             102
#  headache                        102
#  bruising                        102
#  swelling_joints                 102
#  anxiety                         102
#  skin_peeling                    102
#  cold_hands_and_feets             96
#  ulcers_on_tongue                 90
#  blister                          90
#  neck_pain                        90
#  blackheads                       90
# ...

# %%
data2.Symptom_3.unique()
# Out:
# array([' nodal_skin_eruptions', ' dischromic _patches', ' chills',
#        ' watering_from_eyes', ' ulcers_on_tongue', ' vomiting',
#        ' yellowish_skin', ' nausea', ' stomach_pain',
#        ' burning_micturition', ' abdominal_pain', ' loss_of_appetite',
#        ' high_fever', ' extra_marital_contacts', ' restlessness',
#        ' lethargy', ' dehydration', ' diarrhoea', ' breathlessness',
#        ' dizziness', ' loss_of_balance', ' headache',
#        ' blurred_and_distorted_vision', ' neck_pain',
#        ' weakness_of_one_body_side', ' altered_sensorium', ' fatigue',
#        ' weight_loss', ' sweating', ' joint_pain', ' dark_urine',
#        ' swelling_of_stomach', ' cough', ' pain_in_anal_region',
#        ' bloody_stool', ' chest_pain', ' bruising', ' obesity',
#        ' cold_hands_and_feets', ' mood_swings', ' anxiety', ' knee_pain',
#        ' hip_joint_pain', ' swelling_joints', ' movement_stiffness',
#        ' spinning_movements', ' blackheads', ' scurring',
# ...

# %%
data2.Symptom_3.nunique()
# Out:
# 54

# %%
data2
# Out:
#                                       Disease             Symptom_1  \
# 0                            Fungal infection               itching
# 1                            Fungal infection             skin_rash
# 2                            Fungal infection               itching
# 3                            Fungal infection               itching
# 4                            Fungal infection               itching
# ...                                       ...                   ...
# 4915  (vertigo) Paroymsal  Positional Vertigo              vomiting
# 4916                                     Acne             skin_rash
# 4917                  Urinary tract infection   burning_micturition
# 4918                                Psoriasis             skin_rash
# 4919                                 Impetigo             skin_rash
#
#                   Symptom_2              Symptom_3                  Symptom_4  \
# ...

# %%
pd.crosstab(data2.Disease,data2.Symptom_1)
# Out:
# Symptom_1                                 acidity   back_pain  \
# Disease
# (vertigo) Paroymsal  Positional Vertigo         0           0
# AIDS                                            0           0
# Acne                                            0           0
# Alcoholic hepatitis                             0           0
# Allergy                                         0           0
# Arthritis                                       0           0
# Bronchial Asthma                                0           0
# Cervical spondylosis                            0         108
# Chicken pox                                     0           0
# Chronic cholestasis                             0           0
# Common Cold                                     0           0
# Dengue                                          0           0
# Diabetes                                        0           0
# Dimorphic hemmorhoids(piles)                    0           0
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame({
    'gender': ['male', 'male', 'female', 'female', 'male', 'female', 'male', 'female'],
    'education_level': ['high school', 'college', 'college', 'graduate', 'high school', 'graduate', 'college', 'graduate'],
    'score': [75, 82, 88, 95, 69, 92, 78, 85]
})

# %%
df
# Out:
#    gender education_level  score
# 0    male     high school     75
# 1    male         college     82
# 2  female         college     88
# 3  female        graduate     95
# 4    male     high school     69
# 5  female        graduate     92
# 6    male         college     78
# 7  female        graduate     85

# %%
normi=pd.crosstab(df.gender, df.education_level)

# %%
normi
# Out:
# education_level  college  graduate  high school
# gender
# female                 1         3            0
# male                   2         0            2

# %%
normi.plot(kind="bar")
# Out:
# <Axes: xlabel='gender'>

# %%
normi
# Out:
# education_level  college  graduate  high school
# gender
# female                 1         3            0
# male                   2         0            2

# %%
data2
# Out:
#                                       Disease             Symptom_1  \
# 0                            Fungal infection               itching
# 1                            Fungal infection             skin_rash
# 2                            Fungal infection               itching
# 3                            Fungal infection               itching
# 4                            Fungal infection               itching
# ...                                       ...                   ...
# 4915  (vertigo) Paroymsal  Positional Vertigo              vomiting
# 4916                                     Acne             skin_rash
# 4917                  Urinary tract infection   burning_micturition
# 4918                                Psoriasis             skin_rash
# 4919                                 Impetigo             skin_rash
#
#                   Symptom_2              Symptom_3                  Symptom_4  \
# ...

# %%
data2.Symptom_1.plot(kind="hist")df.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 data2.Symptom_1.plot(kind="hist")
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:975, in PlotAccessor.__call__(self, *args, **kwargs)
#     972             label_name = label_kw or data.columns
#     973             data.columns = label_name
# --> 975 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:446, in MPLPlot.generate(self)
#     444 def generate(self) -> None:
# ...

# %%
df
# Out:
#    gender education_level  score
# 0    male     high school     75
# 1    male         college     82
# 2  female         college     88
# 3  female        graduate     95
# 4    male     high school     69
# 5  female        graduate     92
# 6    male         college     78
# 7  female        graduate     85

# %%
df.score.plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
data2.Symptom_1.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Symptom_1'>

# %%
data2
# Out:
#                                       Disease             Symptom_1  \
# 0                            Fungal infection               itching
# 1                            Fungal infection             skin_rash
# 2                            Fungal infection               itching
# 3                            Fungal infection               itching
# 4                            Fungal infection               itching
# ...                                       ...                   ...
# 4915  (vertigo) Paroymsal  Positional Vertigo              vomiting
# 4916                                     Acne             skin_rash
# 4917                  Urinary tract infection   burning_micturition
# 4918                                Psoriasis             skin_rash
# 4919                                 Impetigo             skin_rash
#
#                   Symptom_2              Symptom_3                  Symptom_4  \
# ...

# %%
df
# Out:
#    gender education_level  score
# 0    male     high school     75
# 1    male         college     82
# 2  female         college     88
# 3  female        graduate     95
# 4    male     high school     69
# 5  female        graduate     92
# 6    male         college     78
# 7  female        graduate     85

# %%
df=pd.DataFrame(columns=["score","gender","education_level"])

# %%
df
# Out:
# Empty DataFrame
# Columns: [score, gender, education_level]
# Index: []

# %%
df
# Out:
# Empty DataFrame
# Columns: [score, gender, education_level]
# Index: []

# %%
df.index=["one","two","three","four","five","six","seven","eight"]

# %%
df
# Out:
#        gender education_level  score
# one      male     high school     75
# two      male         college     82
# three  female         college     88
# four   female        graduate     95
# five     male     high school     69
# six    female        graduate     92
# seven    male         college     78
# eight  female        graduate     85

# %%
df.loc[["two","seven","one"],["gender"]]
# Out:
#       gender
# two     male
# seven   male
# one     male

# %%
df.loc[:]
# Out:
#        gender education_level  score
# one      male     high school     75
# two      male         college     82
# three  female         college     88
# four   female        graduate     95
# five     male     high school     69
# six    female        graduate     92
# seven    male         college     78
# eight  female        graduate     85

# %%
df.loc[["one","five","six"]]
# Out:
#       gender education_level  score
# one     male     high school     75
# five    male     high school     69
# six   female        graduate     92

# %%
df["score"]=18

# %%
df
# Out:
#        gender education_level  score
# one      male     high school     18
# two      male         college     18
# three  female         college     18
# four   female        graduate     18
# five     male     high school     18
# six    female        graduate     18
# seven    male         college     18
# eight  female        graduate     18

# %%
df
# Out:
#    gender education_level  score
# 0    male     high school     75
# 1    male         college     82
# 2  female         college     88
# 3  female        graduate     95
# 4    male     high school     69
# 5  female        graduate     92
# 6    male         college     78
# 7  female        graduate     85

# %%
df["pass"]=df.score>=75

# %%
df
# Out:
#    gender education_level  score   pass
# 0    male     high school     75   True
# 1    male         college     82   True
# 2  female         college     88   True
# 3  female        graduate     95   True
# 4    male     high school     69  False
# 5  female        graduate     92   True
# 6    male         college     78   True
# 7  female        graduate     85   True

# %%
df["pass"]=df.score>=60

# %%
df
# Out:
#    gender education_level  score  pass
# 0    male     high school     75  True
# 1    male         college     82  True
# 2  female         college     88  True
# 3  female        graduate     95  True
# 4    male     high school     69  True
# 5  female        graduate     92  True
# 6    male         college     78  True
# 7  female        graduate     85  True

# %%
df["pass"]=df.score>=85

# %%
df
# Out:
#    gender education_level  score   pass
# 0    male     high school     75  False
# 1    male         college     82  False
# 2  female         college     88   True
# 3  female        graduate     95   True
# 4    male     high school     69  False
# 5  female        graduate     92   True
# 6    male         college     78  False
# 7  female        graduate     85   True

# %%
del df["pass"]

# %%
df
# Out:
#    gender education_level  score
# 0    male     high school     75
# 1    male         college     82
# 2  female         college     88
# 3  female        graduate     95
# 4    male     high school     69
# 5  female        graduate     92
# 6    male         college     78
# 7  female        graduate     85

# %%
scores={"Maths":{"A":20,"B":25,"C":30},"Science":{"A":22,"B":27,"C":32}}

# %%
scores
# Out:
# {'Maths': {'A': 20, 'B': 25, 'C': 30}, 'Science': {'A': 22, 'B': 27, 'C': 32}}

# %%
scores_df=pd.DataFrame(scores)

# %%
scores_df
# Out:
#    Maths  Science
# A     20       22
# B     25       27
# C     30       32

# %%
scores_df.T
# Out:
#           A   B   C
# Maths    20  25  30
# Science  22  27  32

# %%
scores_df
# Out:
#    Maths  Science
# A     20       22
# B     25       27
# C     30       32

# %%
scores_df.index.name="s_no"
scores_df.columns.name="head"

# %%
scores_df
# Out:
# head  Maths  Science
# s_no
# A        20       22
# B        25       27
# C        30       32

# %%
scores_df.values
# Out:
# array([[20, 22],
#        [25, 27],
#        [30, 32]], dtype=int64)

# %%
scores_df.index
# Out:
# Index(['A', 'B', 'C'], dtype='object', name='s_no')

# %%
obj=pd.Series([5,6,7,8,9], index=["A","B","C","D","E"])

# %%
obj
# Out:
# A    5
# B    6
# C    7
# D    8
# E    9
# dtype: int64

# %%
obj[["A","D"]]
# Out:
# A    5
# D    8
# dtype: int64

# %%
obj[[2,4]]
# Out:
# C    7
# E    9
# dtype: int64

# %%
obj[obj>6]
# Out:
# C    7
# D    8
# E    9
# dtype: int64

# %%
obj["D":"E"]=5

# %%
obj
# Out:
# A    5
# B    6
# C    7
# D    5
# E    5
# dtype: int64

# %%
import numpy as np

# %%
np.__version__
# Out:
# '1.24.3'

# %%
data4=pd.DataFrame(np.arange(20).reshape(5,4),columns=["one","two","three","four"],index=["a","b","c","d","e"])
data4
# Out:
#    one  two  three  four
# a    0    1      2     3
# b    4    5      6     7
# c    8    9     10    11
# d   12   13     14    15
# e   16   17     18    19

# %%
data4[["three","two"]]
# Out:
#    three  two
# a      2    1
# b      6    5
# c     10    9
# d     14   13
# e     18   17

# %%
data4[:]
# Out:
#    one  two  three  four
# a    0    1      2     3
# b    4    5      6     7
# c    8    9     10    11
# d   12   13     14    15
# e   16   17     18    19

# %%
data4[:3]
# Out:
#    one  two  three  four
# a    0    1      2     3
# b    4    5      6     7
# c    8    9     10    11

# %%
data4[data4>=6]
# Out:
#     one   two  three  four
# a   NaN   NaN    NaN   NaN
# b   NaN   NaN    6.0   7.0
# c   8.0   9.0   10.0  11.0
# d  12.0  13.0   14.0  15.0
# e  16.0  17.0   18.0  19.0

# %%
data4
# Out:
#    one  two  three  four
# a    0    1      2     3
# b    4    5      6     7
# c    8    9     10    11
# d   12   13     14    15
# e   16   17     18    19

# %%
data4[data4["one"]>=5]
# Out:
#    one  two  three  four
# c    8    9     10    11
# d   12   13     14    15
# e   16   17     18    19

# %%
data4[data4>6]="-"

# %%
data4
# Out:
#   one two three four
# a   0   1     2    3
# b   4   5     6    -
# c   -   -     -    -
# d   -   -     -    -
# e   -   -     -    -

# %%
data4
# Out:
#    one  two  three  four
# a    0    1      2     3
# b    4    5      6     7
# c    8    9     10    11
# d   12   13     14    15
# e   16   17     18    19

# %%
data4.loc[["b","d"],["three"]]
# Out:
#    three
# b      6
# d     14

# %%
data4.iloc[[3],[1,3]]
# Out:
#    two  four
# d   13    15

# %%
data4.iloc[[0,4],1:4]
# Out:
#    two  three  four
# a    1      2     3
# e   17     18    19

# %%
data4
# Out:
#    one  two  three  four
# a    0    1      2     3
# b    4    5      6     7
# c    8    9     10    11
# d   12   13     14    15
# e   16   17     18    19

# %%
data4.iloc[1:4,1:3]
# Out:
#    two  three
# b    5      6
# c    9     10
# d   13     14

# %%
data4.iloc[1]
# Out:
# one      4
# two      5
# three    6
# four     7
# Name: b, dtype: int32

# %%
type(data4.iloc[1])
# Out:
# pandas.core.series.Series

# %%
data4
# Out:
#    one  two  three  four
# a    0    1      2     3
# b    4    5      6     7
# c    8    9     10    11
# d   12   13     14    15
# e   16   17     18    19

# %%
data4.loc["b":"e","two":"four"]
# Out:
#    two  three  four
# b    5      6     7
# c    9     10    11
# d   13     14    15
# e   17     18    19

# %%
data4.loc[["b","e"]]
# Out:
#    one  two  three  four
# b    4    5      6     7
# e   16   17     18    19

# %%
data4
# Out:
#    one  two  three  four
# a    0    1      2     3
# b    4    5      6     7
# c    8    9     10    11
# d   12   13     14    15
# e   16   17     18    19

# %%
data4.loc["c",["three","four"]]
# Out:
# three    10
# four     11
# Name: c, dtype: int32

# %%
data4.loc[["b","c","d"],"three"]
# Out:
# b     6
# c    10
# d    14
# Name: three, dtype: int32

# %%
table=pd.read_html("https://en.wikipedia.org/wiki/Animal")

# %%
table[1]
# Out:
#                                                Phylum  \
# 0                                          Arthropoda
# 1                                            Mollusca
# 2                                            Chordata
# 3                                     Platyhelminthes
# 4                                            Nematoda
# 5                                            Annelida
# 6                                            Cnidaria
# 7                                            Porifera
# 8                                       Echinodermata
# 9                                             Bryozoa
# 10                                           Rotifera
# 11                                           Nemertea
# 12                                         Tardigrada
# 13  Total number of described extant species as of...
#
#                                               Example  \
# 0                                                 NaN
# ...

# %%
wiki=pd.read_html("https://en.wikipedia.org/wiki/Minnesota")

# %%
wiki[3]
# Out:
#    Largest cities or towns in Minnesota Source:[83]                         \
#                                  Unnamed: 0_level_1                   Rank
# 0                            Minneapolis Saint Paul                      1
# 1                            Minneapolis Saint Paul                      2
# 2                            Minneapolis Saint Paul                      3
# 3                            Minneapolis Saint Paul                      4
# 4                            Minneapolis Saint Paul                      5
# 5                            Minneapolis Saint Paul                      6
# 6                            Minneapolis Saint Paul                      7
# 7                            Minneapolis Saint Paul                      8
# 8                            Minneapolis Saint Paul                      9
# 9                            Minneapolis Saint Paul                     10
# ...
